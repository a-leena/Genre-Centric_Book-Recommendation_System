# %%
import networkx as nx
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import random
from networkx.algorithms import community
import numpy as np

# %%
# Load the dataset
dataset_path = "Processed_BookData.csv"
df = pd.read_csv(dataset_path)

# sample for testing
random.seed(74)  # for reproducibility
selected_rows = random.sample(range(len(df)), int(0.01 * len(df)))
df_sample = df.iloc[selected_rows]

# %%
len(set(df_sample['book_authors'].values))
# Out:
# 346

# %%
# Load the communities
communities_set_path = "Communities_1%_BookData.csv"
communities_df = pd.read_csv(communities_set_path)

authors = set(communities_df['Author1'].values).union(set(communities_df['Author2'].values))
len(authors)
# Out:
# 346

# %%
def showBooks():
    count=0
    for book in df_sample['book_title'].values:
        count += 1
        print(count,end=".\t")
        print(book)

# %%
def get_all_authors (author):
    other_authors = {}
    results1 = communities_df.loc[communities_df['Author1']==author].values
    
    if len(results1)!=0:
        for res in results1:
            other_authors[res[1]] = res[2]
    
    results2 = communities_df.loc[communities_df['Author2']==author].values
    if len(results2)!=0:
        for res in results2:
            if other_authors.get(res[0]) is None:
                other_authors[res[0]] = res[2]
            
    sorted_authors = sorted(other_authors.items(), key = lambda x: x[1], reverse=True)
    
    # top_n_authors = dict(sorted_authors[:n])
    
    return dict(sorted_authors).keys()

# %%
# recs = get_all_authors('Henrietta Clarke')

# # print(recs)
# for rec in recs:
#     print(rec)

# %%
def get_n_books(authors,n):
    filtered_df = df_sample[df_sample['book_authors'].isin(authors)]
    books = {}
    for _, row in filtered_df.iterrows():
        books[row['book_title']] = {"author": row['book_authors'], "rating": row['book_rating'] * row['book_rating_count']}
    # print(books.items())   
    sorted_books = sorted(books.items(), key = lambda x:x[1]['rating'], reverse=True)
    results = {}
    # print(dict(sorted_books).keys())
    for book in dict(sorted_books).keys():
        # print(dict(sorted_books)[book])
        results[book] = dict(sorted_books)[book]['author']
    # print(results.items())
    if (len(books.keys()) <= n):
        return results.items()
    
    else:
        top_n_books = list(results.items())[:n]
        return top_n_books

# %%
# get_n_books(recs,30)

# %%
def searchBook():
    book_title = input("Enter title of the book to search: ")
    n = int(input("Enter the numebr of book recommendations to get: "))
    
    search = df_sample[df_sample['book_title']==book_title]
    
    if len(search.values) != 0 :
        author = search.values[0][0]
        num_pages = search.values[0][1]
        book_rating = search.values[0][2]
        book_rating_count = search.values[0][3]
        genres = search.values[0][6].split(",")
        # print(search)
        print()
        print("Book Title:", book_title)
        print("Author:", author)
        print("Number of Pages:", num_pages)
        print("Rating:", book_rating)
        print("Number of Ratings:", book_rating_count)
        print("Genres:",genres)
        
        print()
        print("\n----- Other Books you may like ------\n")
        recs = get_n_books(get_all_authors(author),n)
        count=0
        for rec in recs:
            count+=1
            print(count,end=".\t")
            print(rec[0],"by",rec[1])
        print()
        
    else:
        print("----- Sorry Book not found -----")

# %% [markdown]
# User can choose and enter a book title (from the below list) and they will be shown the details of that book and recommendations of similar books

# %% [markdown]
# 1. Enter the book title
# 2. Enter the number of book recommendations to get => m
#
# **input box comes at the top of the screen**

# %%
showBooks()
# Out:
# 1.	Burlian
# 2.	Third Grave Dead Ahead
# 3.	The Sisters Who Would Be Queen: Mary, Katherine, and Lady Jane Grey: A Tudor Tragedy
# 4.	Unemployable!
# 5.	Glimpses of Unfamiliar Japan
# 6.	The Contest
# 7.	Pauliska, ou la perversité moderne
# 8.	The Study Series Bundle
# 9.	Love, Dishonor, Marry, Die, Cherish, Perish
# 10.	The Patchwork House
# 11.	Sunshine
# 12.	The Future Eaters: An Ecological History of the Australasian Lands and People
# 13.	Avoiding Commitment
# 14.	Succubus Blues
# 15.	Guy Noir and the Straight Skinny
# 16.	Rhapsodic
# 17.	Daughter of the Earth and Sky
# 18.	The Grey King
# 19.	The Complete Photo Guide to Hand Lettering and Calligraphy: The Essential Reference for Novice and Expert Letterers and Calligraphers
# 20.	Water Walker
# 21.	Until Jax
# 22.	Bleeding Violet
# 23.	Fame, Glory, and Other Things on My To Do List
# 24.	Great Mysteries of the Past: Experts Unravel Fact and Fallacy Behind the Headlines of History
# 25.	Taken
# 26.	The Blackhouse
# 27.	Acceptance
# 28.	The Housewife Assassin's Handbook
# 29.	The Death of Grass
# 30.	The October Country
# 31.	BARBATUS
# 32.	Reclaim Your Heart: Personal Insights on Breaking Free from Life's Shackles
# 33.	Hyinen hauta
# 34.	Free to a Good Home
# 35.	No sonrías, que me enamoro
# 36.	A Small Place
# 37.	Renegade
# 38.	A Wish Made Of Glass
# 39.	Legally Blonde
# 40.	Don't Judge a Girl by Her Cover
# 41.	Secrets of the Tudor Court
# 42.	Killing Me Softly
# 43.	Prey
# 44.	Fango
# 45.	Unraveling
# 46.	Children Of The Shroud
# 47.	The Legend of the Firefish
# 48.	The Boomer Bible
# 49.	Suddenly a Bride
# 50.	Bellazard: When the Dragons Went Missing
# 51.	January First: A Child's Descent into Madness and Her Father's Struggle to Save Her
# 52.	Some Girls Are
# 53.	Roses for Mama
# 54.	The Fionavar Tapestry
# 55.	Howling for My Baby
# 56.	Kenobi's Blade
# 57.	Shot Down: The True Story of Pilot Howard Snyder and the Crew of the B-17 Susan Ruth
# 58.	Demon Road
# 59.	Sand Daughter
# 60.	Warriors: The Untold Stories
# 61.	Secrets of the Tides
# 62.	Chasing After Infinity
# 63.	Barbe bleue
# 64.	The Goblin Emperor
# 65.	2001 Nights: The Death Trilogy Overture
# 66.	The Bitten
# 67.	Om, the Secret of Ahbor Valley
# 68.	The Selection
# 69.	Never Go Back
# 70.	Bondslave
# 71.	For Reasons Unknown
# 72.	America's Real War
# 73.	Warrior Chicks: Rising Strong, Beautiful and Confident
# 74.	K-PAX The Trilogy
# 75.	In Cold Blood
# 76.	Twilight Phantasies
# 77.	Star of Light
# 78.	Wicked Appetite
# 79.	Stolen
# 80.	The Desert Princess (The Sultan's Heir, #2)
# 81.	Lightning
# 82.	Devour
# 83.	The Black Dagger Brotherhood: An Insider's Guide
# 84.	Um Sopro de Neve e Cinzas, parte 1
# 85.	Something Like What It's Supposed to Be...
# 86.	The Highwayman Came Waltzing
# 87.	Politics - According to the Bible: A Comprehensive Resource for Understanding Modern Political Issues in Light of Scripture
# 88.	The Beautiful Room Is Empty
# 89.	Where the Heart Is
# 90.	Angel-Seeker
# 91.	The Starlight Rite
# 92.	City of Bohane
# 93.	The Enemy Within: The Secret War Against the Miners
# 94.	The Yellow Wallpaper
# 95.	Brewer's Famous Quotations: 5000 Quotations and the Stories Behind Them
# 96.	La bibliotecaria de Auschwitz
# 97.	Kinyas ve Kayra
# 98.	Never Just a Memory
# 99.	A Demon Made Me Do It
# 100.	Finding Audrey
# 101.	The Secret Life of Bees
# 102.	Butterfly Weed
# 103.	A Quality Of Light
# 104.	December
# 105.	The Once and Future King
# 106.	V is for Virgin
# 107.	Last Ride
# 108.	Bully Boy Blue
# 109.	Delhi Is Not Far
# 110.	The Magic Labyrinth
# 111.	The Truth About Riley
# 112.	Sharp Objects
# 113.	Darkness Falls
# 114.	Prince of Dogs
# 115.	El viejo y el mar
# 116.	Contengan Jalanan
# 117.	The Devil of Nanking
# 118.	The Last Chapter
# 119.	Andrew Carnegie
# 120.	Spook's: Alice
# 121.	The Queen of the Tearling
# 122.	A Devil and Her Love Song, Vol. 1
# 123.	Okay for Now
# 124.	The Last Days
# 125.	On the Edge of Gone
# 126.	Slow Heat
# 127.	The Forgotten Highlander: My Incredible Story of Survival During the War in the Far East
# 128.	The Awful Apple Orchard
# 129.	Summer of Sloane
# 130.	Incidents in the Life of a Slave Girl
# 131.	Dead Time
# 132.	Trinity
# 133.	Ysabel
# 134.	The Green Fool
# 135.	The Keatyn Chronicles: Books 1-3
# 136.	Sookie Stackhouse 8 Volume Set
# 137.	Who Will Cry When You Die?- Hindi
# 138.	Between the Devil and the Deep Blue Sea
# 139.	Un monstruo viene a verme
# 140.	Fearless: The Heroic Story of One Navy SEAL's Sacrifice in the Hunt for Osama Bin Laden and the Unwavering Devotion of the Woman Who Loved Him
# 141.	The Prince of Thieves
# 142.	Mars, Volume 01
# 143.	Until That Distant Day
# 144.	The Guaymas Chronicles: La Mandadera
# 145.	Playlist for the Dead
# 146.	The One Year Devos for Animal Lovers: Cool Things Animals Show Us about Our Creator
# 147.	Brighton Beach Memoirs
# 148.	Seawitch
# 149.	Dreamstrider
# 150.	Thirty Nights with a Highland Husband
# 151.	Come Find Me
# 152.	Perfect
# 153.	Killing Pablo: The Hunt for the World's Greatest Outlaw
# 154.	Shakespeare: The Invention of the Human
# 155.	The Death Sculptor
# 156.	Grace's Guide: The Art of Pretending to Be a Grown-up
# 157.	The Chronicles of a Crazy Chick
# 158.	Battle Lines
# 159.	What My Mother Doesn't Know
# 160.	Street Haunting
# 161.	The Stories of Eva Luna
# 162.	The Invisible Circus
# 163.	Tortured for Christ
# 164.	Searching
# 165.	Il barone rampante
# 166.	Rio's World
# 167.	The Red Tent
# 168.	Mohawk Trail
# 169.	The Book of Sorrows
# 170.	Shadow
# 171.	The Evolution of Ethan Poe
# 172.	Arrugas
# 173.	Resurrection
# 174.	Misery
# 175.	Rabbit Is Rich
# 176.	Pintu Terlarang
# 177.	Flutter
# 178.	The Sixteen Pleasures
# 179.	One False Move
# 180.	The IHOP Papers
# 181.	Rise of Empire
# 182.	To the Edge
# 183.	The Singing
# 184.	Unforgettable
# 185.	The Firebrand
# 186.	Bestrafe mich!
# 187.	Tainted Black
# 188.	For Cheddar or Worse
# 189.	Everything Is Illuminated
# 190.	The Jesus I Never Knew
# 191.	Magical Thinking: True Stories
# 192.	The Blind Mirror
# 193.	When Dreams Come True: A Love Story Only God Could Write
# 194.	God is Just: A Defense of the Old Testament Civil Laws
# 195.	Confessions of a Tween Superheroine (The Dunk'N Divaz #1)
# 196.	The Muse
# 197.	Ang Paboritong Libro ni Hudas
# 198.	Lit
# 199.	The Old River Road
# 200.	The Storm Begins
# 201.	Forever Scarred
# 202.	A Common Story: A Novel (Classics of Russian Literature)
# 203.	The Drunkard's Walk: How Randomness Rules Our Lives
# 204.	Troika
# 205.	The Fiery Cross
# 206.	Once Is Not Enough
# 207.	The Miracle Of Castel Di Sangro
# 208.	Until You
# 209.	The New Girls
# 210.	The Slave Auction (Scotia Saga #1)
# 211.	Word of Honor
# 212.	Ripple
# 213.	Fangirl
# 214.	Stripped
# 215.	Misteriosa Buenos Aires
# 216.	Truth or Dare
# 217.	The Way of Zen
# 218.	The Rebels
# 219.	Blood Beast
# 220.	You Remind Me of Me
# 221.	Wishing for a Highlander
# 222.	Slade House
# 223.	Jack Who?: Perfect Storms
# 224.	Los renglones torcidos de Dios
# 225.	Friday the Rabbi Slept Late
# 226.	The Wall
# 227.	Blestemul Vraciului
# 228.	The Sun Is Also a Star
# 229.	Trouble
# 230.	Missing Persons
# 231.	Surrender to Fate
# 232.	Paul à Québec
# 233.	A Monster Calls
# 234.	Starkissed
# 235.	Wildlife
# 236.	Glimpses of Unfamiliar Japan, Vol.2
# 237.	The Six-Gun Tarot
# 238.	A Beautiful Evil
# 239.	Ghost Wars: The Secret History of the CIA, Afghanistan, and bin Laden from the Soviet Invasion to September 10, 2001
# 240.	Before I Wake
# 241.	You Have a Brain: A Teen's Guide to T.H.I.N.K. B.I.G.
# 242.	Dead Sleep
# 243.	Mr. Popular and I
# 244.	Paul's Dream
# 245.	Olivia Kidney and the Exit Academy
# 246.	More Than Her
# 247.	Winterdance: The Fine Madness of Running the Iditarod
# 248.	The Winter Sword
# 249.	Still Alice
# 250.	The Dancing Column: On Order in Architecture
# 251.	When I Was a Slave: Memoirs from the Slave Narrative Collection
# 252.	How I Live Now
# 253.	Secrets of a Summer Night
# 254.	Protector of the Realm
# 255.	Happy Women Live Better
# 256.	Red Queen
# 257.	The Mummy
# 258.	Rinko Kawauchi: Ametsuchi
# 259.	Blue exorcist, Tome 2
# 260.	Out Of Range
# 261.	A Kiss from Maddalena
# 262.	El otro barrio
# 263.	Song of Solomon
# 264.	The Fixed Trilogy (Fixed, #1-3)
# 265.	Foe
# 266.	Player Piano
# 267.	Blood Moon
# 268.	Pleasure
# 269.	Runemarks
# 270.	Wolf Signs
# 271.	Whisper Kiss
# 272.	As We Forgive: Stories of Reconciliation from Rwanda
# 273.	The Art of Racing in the Rain
# 274.	Hillary: Flesh and Blood
# 275.	Glass Sword
# 276.	sTORI Telling
# 277.	Bakit Hindi Ka Crush ng Crush Mo?
# 278.	El Perfume: Historia De Un Asesino
# 279.	El amante japonés
# 280.	The Uncanny
# 281.	The Book of Three
# 282.	The Unbecoming of Mara Dyer
# 283.	Married To A Deadly Bitch 2
# 284.	Vendetta or the Story of One Forgotten
# 285.	Don't Tell Mum I Work On The Rigs, She Thinks I'm A Piano Player In A Whorehouse
# 286.	The Whereabouts of Eneas McNulty
# 287.	Choosing Light: When an Earthquake Buried Me and My Family for 5 Days, I Learned to Fully Live
# 288.	Confessions of Emergency Room Doctors
# 289.	Nightfall and Other Stories
# 290.	The Boy Who Couldn't Die
# 291.	Guide to the Sabbat
# 292.	The Island Stallion
# 293.	The I-5 Killer
# 294.	Conquest: Montezuma, Cortes and the Fall of Old Mexico
# 295.	Homecoming
# 296.	Crazy Horse and Custer
# 297.	Apt Pupil
# 298.	Elephant Man
# 299.	Styxx
# 300.	Five Little Peppers and How They Grew
# 301.	Another Chance to Dream
# 302.	If There Be Thorns
# 303.	Nero Corleone
# 304.	The Golden Braid
# 305.	Black and Blue
# 306.	La busca
# 307.	Fade Away
# 308.	Writing About Villains
# 309.	Sahara Special
# 310.	The Woods
# 311.	Carry On
# 312.	Ruler of the Realm
# 313.	From Time to Time
# 314.	All's Fair in Love & Seduction
# 315.	Burning Desire
# 316.	Saved at Sunrise
# 317.	Louis Armstrong: An Extravagant Life
# 318.	Remembering the Bones
# 319.	Hero
# 320.	Now This War Has Two Sides
# 321.	Know No Fear
# 322.	Lovely Wicked
# 323.	Dead Until Dark
# 324.	Craving's Creek
# 325.	Double Time
# 326.	Grey: The Covenant of Shadows
# 327.	Five, Six, Seven, Nate!
# 328.	Surprised by Hope: Rethinking Heaven, the Resurrection, and the Mission of the Church
# 329.	Where He Ends and I Begin
# 330.	Nagasasra dan Sabuk Inten
# 331.	13 Little Blue Envelopes
# 332.	Caravans
# 333.	Wicked Intentions
# 334.	The Harsh Cry of the Heron
# 335.	City of Bones
# 336.	Lady Luck
# 337.	Circle Of Five
# 338.	Tainted Bodies
# 339.	Tenggelamnya Kapal Van Der Wijck
# 340.	In The Cemetery Where Al Jolsen is Buried
# 341.	Brother's Keeper
# 342.	S is for Silence
# 343.	The Potted Quiz: Volume Eight
# 344.	Las vidas de los animales
# 345.	Who Put That Hair in My Toothbrush?
# 346.	Sarah Dessen: From Burritos to Box Office
# 347.	Doctor Who: Strange England
# 348.	The Circle
# 349.	Hot Ticket
# 350.	Kick the Candle
# 351.	The Not So Secret Emails Of Coco Pinchard
# 352.	Alcatraz Versus the Scrivener's Bones
# 353.	Fall for Anything
# 354.	Fallen
# 355.	The Visitation
# 356.	The Demonologist: The Extraordinary Career of Ed & Lorraine Warren
# 357.	My Side of the Mountain Trilogy
# 358.	A Day of Glory
# 359.	Who Wrote the Bible?
# 360.	Bound
# 361.	Nooit meer slapen
# 362.	Bidadari Bidadari Surga

# %%
searchBook()
# Out:
# Book Title: Writing About Villains
# Author: Rayne Hall
# Number of Pages: 75
# Rating: 4.23
# Number of Ratings: 145
# Genres: ['Language', 'Nonfiction', 'Writing']
#
#
# ----- Other Books you may like ------
#
# 1.	In Cold Blood by Truman Capote
# 2.	Magical Thinking: True Stories by Augusten Burroughs
# 3.	Incidents in the Life of a Slave Girl by Harriet Ann Jacobs
# 4.	Lit by Mary Karr
# 5.	The Jesus I Never Knew by Philip Yancey
# 6.	The Drunkard's Walk: How Randomness Rules Our Lives by Leonard Mlodinow
# 7.	sTORI Telling by Tori Spelling
# 8.	Fearless: The Heroic Story of One Navy SEAL's Sacrifice in the Hunt for Osama Bin Laden and the Unwavering Devotion of the Woman Who Loved Him by Eric Blehm
# 9.	The Way of Zen by Alan W. Watts
# 10.	Tortured for Christ by Richard Wurmbrand
# 11.	Killing Pablo: The Hunt for the World's Greatest Outlaw by Mark Bowden
# 12.	Who Will Cry When You Die?- Hindi by Robin S. Sharma
# 13.	Ghost Wars: The Secret History of the CIA, Afghanistan, and bin Laden from the Soviet Invasion to September 10, 2001 by Steve Coll
# 14.	Surprised by Hope: Rethinking Heaven, the Resurrection, and the Mission of the Church by N.T. Wright
# 15.	Ang Paboritong Libro ni Hudas by Bob Ong
