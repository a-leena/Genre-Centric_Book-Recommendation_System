# %%
import networkx as nx
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import random
from networkx.algorithms import community
import numpy as np

# %%
# Load the dataset
dataset_path = "Processed_BookData.csv"
df = pd.read_csv(dataset_path)

# sample for testing
random.seed(74)  # for reproducibility
selected_rows = random.sample(range(len(df)), int(0.01 * len(df)))
df_sample = df.iloc[selected_rows]

# %%
len(set(df_sample['book_authors'].values))
# Out:
# 346

# %%
# Load the communities
communities_set_path = "Communities_1%_BookData.csv"
communities_df = pd.read_csv(communities_set_path)

authors = set(communities_df['Author1'].values).union(set(communities_df['Author2'].values))
len(authors)
# Out:
# 346

# %%
count=0
for book in df_sample['book_title'].values:
    print(count,end=".\t")
    print(book)
    count += 1
# Out:
# 0.	Burlian
# 1.	Third Grave Dead Ahead
# 2.	The Sisters Who Would Be Queen: Mary, Katherine, and Lady Jane Grey: A Tudor Tragedy
# 3.	Unemployable!
# 4.	Glimpses of Unfamiliar Japan
# 5.	The Contest
# 6.	Pauliska, ou la perversité moderne
# 7.	The Study Series Bundle
# 8.	Love, Dishonor, Marry, Die, Cherish, Perish
# 9.	The Patchwork House
# 10.	Sunshine
# 11.	The Future Eaters: An Ecological History of the Australasian Lands and People
# 12.	Avoiding Commitment
# 13.	Succubus Blues
# 14.	Guy Noir and the Straight Skinny
# 15.	Rhapsodic
# 16.	Daughter of the Earth and Sky
# 17.	The Grey King
# 18.	The Complete Photo Guide to Hand Lettering and Calligraphy: The Essential Reference for Novice and Expert Letterers and Calligraphers
# 19.	Water Walker
# 20.	Until Jax
# 21.	Bleeding Violet
# 22.	Fame, Glory, and Other Things on My To Do List
# 23.	Great Mysteries of the Past: Experts Unravel Fact and Fallacy Behind the Headlines of History
# 24.	Taken
# 25.	The Blackhouse
# 26.	Acceptance
# 27.	The Housewife Assassin's Handbook
# 28.	The Death of Grass
# 29.	The October Country
# 30.	BARBATUS
# 31.	Reclaim Your Heart: Personal Insights on Breaking Free from Life's Shackles
# 32.	Hyinen hauta
# 33.	Free to a Good Home
# 34.	No sonrías, que me enamoro
# 35.	A Small Place
# 36.	Renegade
# 37.	A Wish Made Of Glass
# 38.	Legally Blonde
# 39.	Don't Judge a Girl by Her Cover
# 40.	Secrets of the Tudor Court
# 41.	Killing Me Softly
# 42.	Prey
# 43.	Fango
# 44.	Unraveling
# 45.	Children Of The Shroud
# 46.	The Legend of the Firefish
# 47.	The Boomer Bible
# 48.	Suddenly a Bride
# 49.	Bellazard: When the Dragons Went Missing
# 50.	January First: A Child's Descent into Madness and Her Father's Struggle to Save Her
# 51.	Some Girls Are
# 52.	Roses for Mama
# 53.	The Fionavar Tapestry
# 54.	Howling for My Baby
# 55.	Kenobi's Blade
# 56.	Shot Down: The True Story of Pilot Howard Snyder and the Crew of the B-17 Susan Ruth
# 57.	Demon Road
# 58.	Sand Daughter
# 59.	Warriors: The Untold Stories
# 60.	Secrets of the Tides
# 61.	Chasing After Infinity
# 62.	Barbe bleue
# 63.	The Goblin Emperor
# 64.	2001 Nights: The Death Trilogy Overture
# 65.	The Bitten
# 66.	Om, the Secret of Ahbor Valley
# 67.	The Selection
# 68.	Never Go Back
# 69.	Bondslave
# 70.	For Reasons Unknown
# 71.	America's Real War
# 72.	Warrior Chicks: Rising Strong, Beautiful and Confident
# 73.	K-PAX The Trilogy
# 74.	In Cold Blood
# 75.	Twilight Phantasies
# 76.	Star of Light
# 77.	Wicked Appetite
# 78.	Stolen
# 79.	The Desert Princess (The Sultan's Heir, #2)
# 80.	Lightning
# 81.	Devour
# 82.	The Black Dagger Brotherhood: An Insider's Guide
# 83.	Um Sopro de Neve e Cinzas, parte 1
# 84.	Something Like What It's Supposed to Be...
# 85.	The Highwayman Came Waltzing
# 86.	Politics - According to the Bible: A Comprehensive Resource for Understanding Modern Political Issues in Light of Scripture
# 87.	The Beautiful Room Is Empty
# 88.	Where the Heart Is
# 89.	Angel-Seeker
# 90.	The Starlight Rite
# 91.	City of Bohane
# 92.	The Enemy Within: The Secret War Against the Miners
# 93.	The Yellow Wallpaper
# 94.	Brewer's Famous Quotations: 5000 Quotations and the Stories Behind Them
# 95.	La bibliotecaria de Auschwitz
# 96.	Kinyas ve Kayra
# 97.	Never Just a Memory
# 98.	A Demon Made Me Do It
# 99.	Finding Audrey
# 100.	The Secret Life of Bees
# 101.	Butterfly Weed
# 102.	A Quality Of Light
# 103.	December
# 104.	The Once and Future King
# 105.	V is for Virgin
# 106.	Last Ride
# 107.	Bully Boy Blue
# 108.	Delhi Is Not Far
# 109.	The Magic Labyrinth
# 110.	The Truth About Riley
# 111.	Sharp Objects
# 112.	Darkness Falls
# 113.	Prince of Dogs
# 114.	El viejo y el mar
# 115.	Contengan Jalanan
# 116.	The Devil of Nanking
# 117.	The Last Chapter
# 118.	Andrew Carnegie
# 119.	Spook's: Alice
# 120.	The Queen of the Tearling
# 121.	A Devil and Her Love Song, Vol. 1
# 122.	Okay for Now
# 123.	The Last Days
# 124.	On the Edge of Gone
# 125.	Slow Heat
# 126.	The Forgotten Highlander: My Incredible Story of Survival During the War in the Far East
# 127.	The Awful Apple Orchard
# 128.	Summer of Sloane
# 129.	Incidents in the Life of a Slave Girl
# 130.	Dead Time
# 131.	Trinity
# 132.	Ysabel
# 133.	The Green Fool
# 134.	The Keatyn Chronicles: Books 1-3
# 135.	Sookie Stackhouse 8 Volume Set
# 136.	Who Will Cry When You Die?- Hindi
# 137.	Between the Devil and the Deep Blue Sea
# 138.	Un monstruo viene a verme
# 139.	Fearless: The Heroic Story of One Navy SEAL's Sacrifice in the Hunt for Osama Bin Laden and the Unwavering Devotion of the Woman Who Loved Him
# 140.	The Prince of Thieves
# 141.	Mars, Volume 01
# 142.	Until That Distant Day
# 143.	The Guaymas Chronicles: La Mandadera
# 144.	Playlist for the Dead
# 145.	The One Year Devos for Animal Lovers: Cool Things Animals Show Us about Our Creator
# 146.	Brighton Beach Memoirs
# 147.	Seawitch
# 148.	Dreamstrider
# 149.	Thirty Nights with a Highland Husband
# 150.	Come Find Me
# 151.	Perfect
# 152.	Killing Pablo: The Hunt for the World's Greatest Outlaw
# 153.	Shakespeare: The Invention of the Human
# 154.	The Death Sculptor
# 155.	Grace's Guide: The Art of Pretending to Be a Grown-up
# 156.	The Chronicles of a Crazy Chick
# 157.	Battle Lines
# 158.	What My Mother Doesn't Know
# 159.	Street Haunting
# 160.	The Stories of Eva Luna
# 161.	The Invisible Circus
# 162.	Tortured for Christ
# 163.	Searching
# 164.	Il barone rampante
# 165.	Rio's World
# 166.	The Red Tent
# 167.	Mohawk Trail
# 168.	The Book of Sorrows
# 169.	Shadow
# 170.	The Evolution of Ethan Poe
# 171.	Arrugas
# 172.	Resurrection
# 173.	Misery
# 174.	Rabbit Is Rich
# 175.	Pintu Terlarang
# 176.	Flutter
# 177.	The Sixteen Pleasures
# 178.	One False Move
# 179.	The IHOP Papers
# 180.	Rise of Empire
# 181.	To the Edge
# 182.	The Singing
# 183.	Unforgettable
# 184.	The Firebrand
# 185.	Bestrafe mich!
# 186.	Tainted Black
# 187.	For Cheddar or Worse
# 188.	Everything Is Illuminated
# 189.	The Jesus I Never Knew
# 190.	Magical Thinking: True Stories
# 191.	The Blind Mirror
# 192.	When Dreams Come True: A Love Story Only God Could Write
# 193.	God is Just: A Defense of the Old Testament Civil Laws
# 194.	Confessions of a Tween Superheroine (The Dunk'N Divaz #1)
# 195.	The Muse
# 196.	Ang Paboritong Libro ni Hudas
# 197.	Lit
# 198.	The Old River Road
# 199.	The Storm Begins
# 200.	Forever Scarred
# 201.	A Common Story: A Novel (Classics of Russian Literature)
# 202.	The Drunkard's Walk: How Randomness Rules Our Lives
# 203.	Troika
# 204.	The Fiery Cross
# 205.	Once Is Not Enough
# 206.	The Miracle Of Castel Di Sangro
# 207.	Until You
# 208.	The New Girls
# 209.	The Slave Auction (Scotia Saga #1)
# 210.	Word of Honor
# 211.	Ripple
# 212.	Fangirl
# 213.	Stripped
# 214.	Misteriosa Buenos Aires
# 215.	Truth or Dare
# 216.	The Way of Zen
# 217.	The Rebels
# 218.	Blood Beast
# 219.	You Remind Me of Me
# 220.	Wishing for a Highlander
# 221.	Slade House
# 222.	Jack Who?: Perfect Storms
# 223.	Los renglones torcidos de Dios
# 224.	Friday the Rabbi Slept Late
# 225.	The Wall
# 226.	Blestemul Vraciului
# 227.	The Sun Is Also a Star
# 228.	Trouble
# 229.	Missing Persons
# 230.	Surrender to Fate
# 231.	Paul à Québec
# 232.	A Monster Calls
# 233.	Starkissed
# 234.	Wildlife
# 235.	Glimpses of Unfamiliar Japan, Vol.2
# 236.	The Six-Gun Tarot
# 237.	A Beautiful Evil
# 238.	Ghost Wars: The Secret History of the CIA, Afghanistan, and bin Laden from the Soviet Invasion to September 10, 2001
# 239.	Before I Wake
# 240.	You Have a Brain: A Teen's Guide to T.H.I.N.K. B.I.G.
# 241.	Dead Sleep
# 242.	Mr. Popular and I
# 243.	Paul's Dream
# 244.	Olivia Kidney and the Exit Academy
# 245.	More Than Her
# 246.	Winterdance: The Fine Madness of Running the Iditarod
# 247.	The Winter Sword
# 248.	Still Alice
# 249.	The Dancing Column: On Order in Architecture
# 250.	When I Was a Slave: Memoirs from the Slave Narrative Collection
# 251.	How I Live Now
# 252.	Secrets of a Summer Night
# 253.	Protector of the Realm
# 254.	Happy Women Live Better
# 255.	Red Queen
# 256.	The Mummy
# 257.	Rinko Kawauchi: Ametsuchi
# 258.	Blue exorcist, Tome 2
# 259.	Out Of Range
# 260.	A Kiss from Maddalena
# 261.	El otro barrio
# 262.	Song of Solomon
# 263.	The Fixed Trilogy (Fixed, #1-3)
# 264.	Foe
# 265.	Player Piano
# 266.	Blood Moon
# 267.	Pleasure
# 268.	Runemarks
# 269.	Wolf Signs
# 270.	Whisper Kiss
# 271.	As We Forgive: Stories of Reconciliation from Rwanda
# 272.	The Art of Racing in the Rain
# 273.	Hillary: Flesh and Blood
# 274.	Glass Sword
# 275.	sTORI Telling
# 276.	Bakit Hindi Ka Crush ng Crush Mo?
# 277.	El Perfume: Historia De Un Asesino
# 278.	El amante japonés
# 279.	The Uncanny
# 280.	The Book of Three
# 281.	The Unbecoming of Mara Dyer
# 282.	Married To A Deadly Bitch 2
# 283.	Vendetta or the Story of One Forgotten
# 284.	Don't Tell Mum I Work On The Rigs, She Thinks I'm A Piano Player In A Whorehouse
# 285.	The Whereabouts of Eneas McNulty
# 286.	Choosing Light: When an Earthquake Buried Me and My Family for 5 Days, I Learned to Fully Live
# 287.	Confessions of Emergency Room Doctors
# 288.	Nightfall and Other Stories
# 289.	The Boy Who Couldn't Die
# 290.	Guide to the Sabbat
# 291.	The Island Stallion
# 292.	The I-5 Killer
# 293.	Conquest: Montezuma, Cortes and the Fall of Old Mexico
# 294.	Homecoming
# 295.	Crazy Horse and Custer
# 296.	Apt Pupil
# 297.	Elephant Man
# 298.	Styxx
# 299.	Five Little Peppers and How They Grew
# 300.	Another Chance to Dream
# 301.	If There Be Thorns
# 302.	Nero Corleone
# 303.	The Golden Braid
# 304.	Black and Blue
# 305.	La busca
# 306.	Fade Away
# 307.	Writing About Villains
# 308.	Sahara Special
# 309.	The Woods
# 310.	Carry On
# 311.	Ruler of the Realm
# 312.	From Time to Time
# 313.	All's Fair in Love & Seduction
# 314.	Burning Desire
# 315.	Saved at Sunrise
# 316.	Louis Armstrong: An Extravagant Life
# 317.	Remembering the Bones
# 318.	Hero
# 319.	Now This War Has Two Sides
# 320.	Know No Fear
# 321.	Lovely Wicked
# 322.	Dead Until Dark
# 323.	Craving's Creek
# 324.	Double Time
# 325.	Grey: The Covenant of Shadows
# 326.	Five, Six, Seven, Nate!
# 327.	Surprised by Hope: Rethinking Heaven, the Resurrection, and the Mission of the Church
# 328.	Where He Ends and I Begin
# 329.	Nagasasra dan Sabuk Inten
# 330.	13 Little Blue Envelopes
# 331.	Caravans
# 332.	Wicked Intentions
# 333.	The Harsh Cry of the Heron
# 334.	City of Bones
# 335.	Lady Luck
# 336.	Circle Of Five
# 337.	Tainted Bodies
# 338.	Tenggelamnya Kapal Van Der Wijck
# 339.	In The Cemetery Where Al Jolsen is Buried
# 340.	Brother's Keeper
# 341.	S is for Silence
# 342.	The Potted Quiz: Volume Eight
# 343.	Las vidas de los animales
# 344.	Who Put That Hair in My Toothbrush?
# 345.	Sarah Dessen: From Burritos to Box Office
# 346.	Doctor Who: Strange England
# 347.	The Circle
# 348.	Hot Ticket
# 349.	Kick the Candle
# 350.	The Not So Secret Emails Of Coco Pinchard
# 351.	Alcatraz Versus the Scrivener's Bones
# 352.	Fall for Anything
# 353.	Fallen
# 354.	The Visitation
# 355.	The Demonologist: The Extraordinary Career of Ed & Lorraine Warren
# 356.	My Side of the Mountain Trilogy
# 357.	A Day of Glory
# 358.	Who Wrote the Bible?
# 359.	Bound
# 360.	Nooit meer slapen
# 361.	Bidadari Bidadari Surga

# %%
def get_n_authors (author,n):
    other_authors = {}
    results1 = communities_df.loc[communities_df['Author1']==author].values
    
    if len(results1)!=0:
        for res in results1:
            other_authors[res[1]] = res[2]
    
    results2 = communities_df.loc[communities_df['Author2']==author].values
    if len(results2)!=0:
        for res in results2:
            if other_authors.get(res[0]) is None:
                other_authors[res[0]] = res[2]
            
    sorted_authors = sorted(other_authors.items(), key = lambda x: x[1], reverse=True)
    
    top_n_authors = dict(sorted_authors[:n])
    
    return top_n_authors.keys()

# %%
recs = get_n_authors('Henrietta Clarke',50)

# print(recs)
for rec in recs:
    print(rec)
# Out:
# Jackie Williams
# Robin Reardon
# T.J. Klune
# Cardeno C.
# Mel Bossa
# Kari Gregg
# Olivia Cunning
# Courtney Summers
# Jacqueline Green
# Cecily von Ziegesar
# Hannah Richell
# Michelle Falkoff
# Kristen Ashley
# Judith McNaught
# Aurora Rose Reynolds
# Jay McLean
# Olivia Evans
# Lora Leigh
# Lorelei James
# Nicola Yoon
# Jill Shalvis
# Samantha Young
# Billie Letts
# thefreakoffreaks
# Blue Jeans
# Cindy Gerard
# Janette Rallison
# Elizabeth Finn
# Non Pratt
# Erin L. Schneider
# K.A. Linde
# Sonya Sones
# Sophie Kinsella
# Kelly Oram
# Adam Pelzman
# Amanda Brown
# Lisa Gillis
# Maureen Johnson
# Robert Bryndza
# Rainbow Rowell
# A. Drew
# Gloria Cook
# Laurelin Paige
# Jillian Dodd
# Jill Stengl
# Ally Carter
# Fuyumi Soryo
# Lynn Kurland
# Lisa Kleypas
# Ray Anselmo

# %%
def get_m_books(authors,m):
    filtered_df = df_sample[df_sample['book_authors'].isin(authors)]
    books = {}
    for _, row in filtered_df.iterrows():
        books[row['book_title']] = {"author": row['book_authors'], "rating": row['book_rating'] * row['book_rating_count']}
    # print(books.items())   
    sorted_books = sorted(books.items(), key = lambda x:x[1]['rating'], reverse=True)
    results = {}
    # print(dict(sorted_books).keys())
    for book in dict(sorted_books).keys():
        # print(dict(sorted_books)[book])
        results[book] = dict(sorted_books)[book]['author']
    # print(results.items())
    if (len(books.keys()) <= m):
        return results.items()
    
    else:
        top_m_books = list(results.items())[:m]
        return top_m_books

# %%
get_m_books(recs,30)
# Out:
# [('Fangirl', 'Rainbow Rowell'),
#  ('Where the Heart Is', 'Billie Letts'),
#  ('Carry On', 'Rainbow Rowell'),
#  ('The Sun Is Also a Star', 'Nicola Yoon'),
#  ('13 Little Blue Envelopes', 'Maureen Johnson'),
#  ("Don't Judge a Girl by Her Cover", 'Ally Carter'),
#  ('Finding Audrey', 'Sophie Kinsella'),
#  ('Secrets of a Summer Night', 'Lisa Kleypas'),
#  ('Lady Luck', 'Kristen Ashley'),
#  ('Avoiding Commitment', 'K.A. Linde'),
#  ('Hero', 'Samantha Young'),
#  ('Hot Ticket', 'Olivia Cunning'),
#  ('Double Time', 'Olivia Cunning'),
#  ('Perfect', 'Judith McNaught'),
#  ('The Fixed Trilogy (Fixed, #1-3)', 'Laurelin Paige'),
#  ('More Than Her', 'Jay McLean'),
#  ('Mars, Volume 01', 'Fuyumi Soryo'),
#  ('Until Jax', 'Aurora Rose Reynolds'),
#  ("What My Mother Doesn't Know", 'Sonya Sones'),
#  ('Some Girls Are', 'Courtney Summers'),
#  ('Legally Blonde', 'Amanda Brown'),
#  ('V is for Virgin', 'Kelly Oram'),
#  ('Slow Heat', 'Jill Shalvis'),
#  ('Playlist for the Dead', 'Michelle Falkoff'),
#  ('Renegade', 'Lora Leigh'),
#  ('Bound', 'Lorelei James'),
#  ('To the Edge', 'Cindy Gerard'),
#  ("Brother's Keeper", 'Elizabeth Finn'),
#  ('Fall for Anything', 'Courtney Summers'),
#  ('No sonrías, que me enamoro', 'Blue Jeans')]

# %% [markdown]
# User can choose and enter a book title (from the above list) and they will be shown the details of that book and recommendations of similar books

# %% [markdown]
# 1. Enter the book title
# 2. Enter the number of authors to fetch from the community => n
# 3. Enter the number of book recommendations to get => m
#
# **input box comes at the top of the screen**

# %%
book_title = input("Enter title of the book to search: ")
book_title
# Out:
# 'Taken'

# %%
n = int(input("Enter the number of authors to fetch from the community: "))
n
# Out:
# 50

# %%
m = int(input("Enter the numebr of book recommendations to get: "))
m
# Out:
# 25

# %%
search = df_sample[df_sample['book_title']==book_title]
if len(search.values) != 0 :
    author = search.values[0][0]
    num_pages = search.values[0][1]
    book_rating = search.values[0][2]
    book_rating_count = search.values[0][3]
    genres = search.values[0][6].split(",")
    # print(search)
    print()
    print("Book Title:", book_title)
    print("Author:", author)
    print("Number of Pages:", num_pages)
    print("Rating:", book_rating)
    print("Number of Ratings:", book_rating_count)
    print("Genres:",genres)
    print()
    print("\n----- Other Books you may like ------\n")
    recs = get_m_books(get_n_authors(author,n),m)
    count=0
    for rec in recs:
        count+=1
        print(count,end=". ")
        print(rec[0],"by",rec[1])
    print()
else:
    print("----- Sorry Book not found -----")
# Out:
# Book Title: Taken
# Author: Erin Bowman
# Number of Pages: 360
# Rating: 3.76
# Number of Ratings: 11122
# Genres: ['Dystopia', 'Fantasy', 'Science Fiction', 'Young Adult']
#
#
# ----- Other Books you may like ------
#
# 1. City of Bones by Cassandra Clare
# 2. The Selection by Kiera Cass
# 3. Dead Until Dark by Charlaine Harris
# 4. Red Queen by Victoria Aveyard
# 5. A Monster Calls by Patrick Ness
# 6. Un monstruo viene a verme by Patrick Ness
# 7. The Fiery Cross by Diana Gabaldon
# 8. The Unbecoming of Mara Dyer by Michelle Hodkin
# 9. Glass Sword by Victoria Aveyard
# 10. The Queen of the Tearling by Erika Johansen
# 11. The Book of Three by Lloyd Alexander
# 12. The Grey King by Susan Cooper
# 13. Acceptance by Jeff VanderMeer
# 14. Blestemul Vraciului by Joseph Delaney
# 15. Unraveling by Elizabeth Norris
# 16. The Goblin Emperor by Katherine Addison
# 17. The Singing by Alison Croggon
# 18. Before I Wake by Rachel Vincent
# 19. The October Country by Ray Bradbury
# 20. Homecoming by Kass Morgan
# 21. Sookie Stackhouse 8 Volume Set by Charlaine Harris
# 22. Blood Beast by Darren Shan
# 23. Alcatraz Versus the Scrivener's Bones by Brandon Sanderson
# 24. The Last Days by Scott Westerfeld
# 25. A Beautiful Evil by Kelly Keaton

# %%
def searchBook():
    book_title = input("Enter title of the book to search: ")
    n = int(input("Enter the number of authors to fetch from the community: "))
    m = int(input("Enter the numebr of book recommendations to get: "))
    search = df_sample[df_sample['book_title']==book_title]
    if len(search.values) != 0 :
        author = search.values[0][0]
        num_pages = search.values[0][1]
        book_rating = search.values[0][2]
        book_rating_count = search.values[0][3]
        genres = search.values[0][6].split(",")
        # print(search)
        print()
        print("Book Title:", book_title)
        print("Author:", author)
        print("Number of Pages:", num_pages)
        print("Rating:", book_rating)
        print("Number of Ratings:", book_rating_count)
        print("Genres:",genres)
        print()
        print("\n----- Other Books you may like ------\n")
        recs = get_m_books(get_n_authors(author,n),m)
        count=0
        for rec in recs:
            count+=1
            print(count,end=". ")
            print(rec[0],"by",rec[1])
        print()
    else:
        print("----- Sorry Book not found -----")

# %%
searchBook()
# Out:
# Book Title: 13 Little Blue Envelopes
# Author: Maureen Johnson
# Number of Pages: 322
# Rating: 3.64
# Number of Ratings: 73983
# Genres: ['Contemporary', 'Fiction', 'Romance', 'Young Adult']
#
#
# ----- Other Books you may like ------
#
# 1. Fangirl by Rainbow Rowell
# 2. Where the Heart Is by Billie Letts
# 3. Carry On by Rainbow Rowell
# 4. The Sun Is Also a Star by Nicola Yoon
# 5. Don't Judge a Girl by Her Cover by Ally Carter
# 6. Finding Audrey by Sophie Kinsella
# 7. Secrets of a Summer Night by Lisa Kleypas
# 8. Lady Luck by Kristen Ashley
# 9. If There Be Thorns by V.C. Andrews
# 10. How I Live Now by Meg Rosoff
# 11. Avoiding Commitment by K.A. Linde
# 12. Hero by Samantha Young
# 13. Hot Ticket by Olivia Cunning
# 14. Double Time by Olivia Cunning
# 15. Perfect by Judith McNaught
# 16. The Fixed Trilogy (Fixed, #1-3) by Laurelin Paige
# 17. More Than Her by Jay McLean
# 18. Mars, Volume 01 by Fuyumi Soryo
# 19. Until Jax by Aurora Rose Reynolds
# 20. What My Mother Doesn't Know by Sonya Sones
